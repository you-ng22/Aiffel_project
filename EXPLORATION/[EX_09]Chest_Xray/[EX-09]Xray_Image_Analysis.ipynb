# %% [markdown]
# # 폐렴 진단해보기

# %% [markdown]
# ## set-up

# %% [markdown]
# 프로젝트에서 사용할 패키지 목룍

# %%
import os, re
import random, math
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings(action='ignore')

# %% [markdown]
# 필요한 변수들을 생성

# %%
# 데이터 로드할 때 빠르게 로드할 수 있도록하는 설정 변수
AUTOTUNE = tf.data.experimental.AUTOTUNE
# X-RAY 이미지 사이즈 변수
IMAGE_SIZE = [180, 180]

# 데이터 경로 변수
ROOT_PATH = os.path.join(os.getenv('HOME'), 'aiffel')
TRAIN_PATH = ROOT_PATH + '/chest_xray/data/train/*/*' # *은 모든 디렉토리와 파일을 의미합니다.
VAL_PATH = ROOT_PATH + '/chest_xray/data/val/*/*'
TEST_PATH = ROOT_PATH + '/chest_xray/data/test/*/*'

# 프로젝트를 진행할 때 아래 두 변수를 변경해보세요
BATCH_SIZE = 64
EPOCHS = 25

print(ROOT_PATH)
# Out:
# /aiffel/aiffel

# %% [markdown]
# ## 데이터 가져오기

# %%
train_filenames = tf.io.gfile.glob(TRAIN_PATH)
test_filenames = tf.io.gfile.glob(TEST_PATH)
val_filenames = tf.io.gfile.glob(VAL_PATH)

print(len(train_filenames))
print(len(test_filenames))
print(len(val_filenames))
# Out:
# 5216
# 624
# 16

# %% [markdown]
# train과 val에 있는 데이터를  train : val를 80:20으로 분할

# %%
# train 데이터와 validation 데이터를 모두 filenames에 담습니다
filenames = tf.io.gfile.glob(TRAIN_PATH)
filenames.extend(tf.io.gfile.glob(VAL_PATH))

# 모아진 filenames를 8:2로 나눕니다
train_size = math.floor(len(filenames)*0.8)
random.seed(8)
random.shuffle(filenames)
train_filenames = filenames[:train_size]
val_filenames = filenames[train_size:]

print(len(train_filenames))
print(len(val_filenames))
# Out:
# 4185
# 1047

# %% [markdown]
# rain 데이터 안에 정상 이미지 수와 폐렴 이미지 수

# %%
print(f'Normal image path\n{filenames[0]}')
print(f'Pneumonia image path\n{filenames[2000]}')
# Out:
# Normal image path
# /aiffel/aiffel/chest_xray/data/train/NORMAL/NORMAL2-IM-1096-0001-0001.jpeg
# Pneumonia image path
# /aiffel/aiffel/chest_xray/data/train/PNEUMONIA/person920_virus_1577.jpeg

# %%
COUNT_NORMAL = len([filename for filename in train_filenames if "NORMAL" in filename])
print(f"Normal images count in training set: {COUNT_NORMAL}")


COUNT_PNEUMONIA = len([filename for filename in train_filenames if "PNEUMONIA" in filename])
print(f"Pneumonia images count in training set: {COUNT_PNEUMONIA}")
# Out:
# Normal images count in training set: 1070
# Pneumonia images count in training set: 3115

# %% [markdown]
# #### tf.data 인스턴스
#
# tf.data는 tensorflow에서 학습시킬 때, mini-batch로 작업할 수 있도록 해 줌

# %%
train_list_ds = tf.data.Dataset.from_tensor_slices(train_filenames)
val_list_ds = tf.data.Dataset.from_tensor_slices(val_filenames)

# %% [markdown]
# Train 데이터셋, validation 데이터셋 개수 확인

# %%
TRAIN_IMG_COUNT = tf.data.experimental.cardinality(train_list_ds).numpy()
print(f"Training images count: {TRAIN_IMG_COUNT}")

VAL_IMG_COUNT = tf.data.experimental.cardinality(val_list_ds).numpy()
print(f"Validating images count: {VAL_IMG_COUNT}")
# Out:
# Training images count: 4185
# Validating images count: 1047

# %% [markdown]
#  라벨 데이터를 만들어 주는 함수

# %%
# 파일 경로의 끝에서 두번째 부분을 확인하면 양성과 음성을 구분할 수 있습니다
def get_label(file_path):
    parts = tf.strings.split(file_path, os.path.sep)
    return parts[-2] == "PNEUMONIA"   # 폐렴이면 양성(True), 노말이면 음성(False)

# %% [markdown]
# ### decode_img 함수와 process_path 함수
#
# process_path 함수에서 decode_img 함수를 이용해서 이미지의 데이터 타입을 float으로 바꾸고 사이즈를 변경

# %%
# 이미지를 알맞은 형식으로 바꿉니다.
def decode_img(img):
    img = tf.image.decode_jpeg(img, channels=3) # 이미지를 uint8 tensor로 수정
    img = tf.image.convert_image_dtype(img, tf.float32) # float32 타입으로 수정
    img = tf.image.resize(img, IMAGE_SIZE) # 이미지 사이즈를 IMAGE_SIZE로 수정
    return img

# 이미지 파일의 경로를 입력하면 이미지와 라벨을 읽어옵니다.
def process_path(file_path):
    label = get_label(file_path) # 라벨 검출
    img = tf.io.read_file(file_path) # 이미지 읽기
    img = decode_img(img) # 이미지를 알맞은 형식으로 수정
    return img, label

# %% [markdown]
# train 데이터 셋과 validation 데이터 셋

# %%
train_ds = train_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
val_ds = val_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

# %%
for image, label in train_ds.take(1):
    print("Image shape: ", image.numpy().shape)
    print("Label: ", label.numpy())
# Out:
# Image shape:  (180, 180, 3)
# Label:  False

# %% [markdown]
#  #### test 데이터셋

# %%
test_list_ds = tf.data.Dataset.list_files(TEST_PATH)
TEST_IMAGE_COUNT = tf.data.experimental.cardinality(test_list_ds).numpy()
test_ds = test_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
test_ds = test_ds.batch(BATCH_SIZE)

print(TEST_IMAGE_COUNT)
# Out:
# 624

# %% [markdown]
# shuffle() 고정 크기 버퍼를 유지, 해당 버퍼에서 무작위로 균일하게 다음 요소를 선택
#
# repeat()  사용한 데이터셋의 경우 여러 번 데이터셋을 사용할 수 있게 해줌
#
# batch()  BATCH_SIZE에서 정한 만큼의 배치로 주어짐
#
# prefetch()  첫 번째 데이터를 GPU에서 학습하는 동안 두 번째 데이터를 CPU에서 준비할 수 있어 리소스의 유휴 상태를 줄일 수 있음

# %%
def prepare_for_training(ds, shuffle_buffer_size=1000):
    ds = ds.shuffle(buffer_size=shuffle_buffer_size)
    ds = ds.repeat()
    ds = ds.batch(BATCH_SIZE)
    ds = ds.prefetch(buffer_size=AUTOTUNE)
    return ds

train_ds = prepare_for_training(train_ds)
val_ds = prepare_for_training(val_ds)

# %% [markdown]
# ## 데이터 시각화

# %%
# 이미지 배치를 입력하면 여러장의 이미지를 보여줍니다.
def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    for n in range(BATCH_SIZE):
        ax = plt.subplot(4,math.ceil(BATCH_SIZE/4),n+1)
        plt.imshow(image_batch[n])
        if label_batch[n]:
            plt.title("PNEUMONIA")
        else:
            plt.title("NORMAL")
        plt.axis("off")


image_batch, label_batch = next(iter(train_ds))
show_batch(image_batch.numpy(), label_batch.numpy())

# %% [markdown]
# ## CNN 모델링

# %% [markdown]
# conv_block()의 구성은 Convolution을 두 번 진행하고 Batch Normalization을 통해서 Gradient vanishing, Gradient Exploding을 해결

# %%
def conv_block(filters):
    block = tf.keras.Sequential([
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPool2D()
    ])
    
    return block

# %%
def dense_block(units, dropout_rate):
    block = tf.keras.Sequential([
        tf.keras.layers.Dense(units, activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(dropout_rate)
    ])
    
    return block

# %%
def build_model():
    model = tf.keras.Sequential([
        tf.keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)),
        
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.MaxPool2D(),
        
        conv_block(32),
        conv_block(64),
        
        conv_block(128),
        tf.keras.layers.Dropout(0.2),
        
        conv_block(256),
        tf.keras.layers.Dropout(0.2),
        
        tf.keras.layers.Flatten(),
        dense_block(512, 0.7),
        dense_block(128, 0.5),
        dense_block(64, 0.3),
        
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])
    
    return model

# %% [markdown]
# ## 데이터 imbalance 처리
#
# #### 클래스 불균형 처리

# %% [markdown]
# #### weight balancing
# - training set의 각 데이터에서 loss를 계산할 때 특정 클래스의 데이터에 더 큰 loss 값을 갖도록 가중치를 부여하는 방법
#
# weight_for_0은 'Normal' 이미지에 사용할 weight를, weight_for_1은 'Pneumonia' 이미지에 사용할 weight를 세팅
#
# weight들은 'Normal'과 'Pneumonia' 전체 데이터 건수에 반비례하도록 설정

# %%
weight_for_0 = (1 / COUNT_NORMAL)*(TRAIN_IMG_COUNT)/2.0 
weight_for_1 = (1 / COUNT_PNEUMONIA)*(TRAIN_IMG_COUNT)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for NORMAL: {:.2f}'.format(weight_for_0))
print('Weight for PNEUMONIA: {:.2f}'.format(weight_for_1))
# Out:
# Weight for NORMAL: 1.96
# Weight for PNEUMONIA: 0.67

# %% [markdown]
# ## 모델 훈련

# %% [markdown]
# build_model()을 model에 선언
#
# "binary_cross entropy" loss를 사용, optimizer로 'adam'을 사용
#
# 성과에 대해서 측정하기 위한 metrics으로 'accuracy', 'precision', 'recall'을 사용

# %% [markdown]
# 모델 fit, 모델 학습

# %%
with tf.device('/GPU:0'):
    model = build_model()

    METRICS = [
        'accuracy',
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]
    
    model.compile(
        optimizer='adam',
        loss='binary_crossentropy',
        metrics=METRICS
    )

# %%
with tf.device('/GPU:0'):
    history = model.fit(
        train_ds,
        steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=val_ds,
        validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
        class_weight=class_weight,
    )
# Out:
# Epoch 1/25
# 65/65 [==============================] - 74s 891ms/step - loss: 0.4322 - accuracy: 0.7933 - precision: 0.9480 - recall: 0.7647 - val_loss: 0.5808 - val_accuracy: 0.7324 - val_precision: 0.7324 - val_recall: 1.0000
# Epoch 2/25
# 65/65 [==============================] - 47s 732ms/step - loss: 0.2096 - accuracy: 0.9197 - precision: 0.9775 - recall: 0.9129 - val_loss: 0.7213 - val_accuracy: 0.7324 - val_precision: 0.7324 - val_recall: 1.0000
# Epoch 3/25
# 65/65 [==============================] - 49s 761ms/step - loss: 0.1624 - accuracy: 0.9428 - precision: 0.9795 - recall: 0.9428 - val_loss: 0.8701 - val_accuracy: 0.7314 - val_precision: 0.7314 - val_recall: 1.0000
# Epoch 4/25
# 65/65 [==============================] - 51s 789ms/step - loss: 0.1219 - accuracy: 0.9538 - precision: 0.9850 - recall: 0.9526 - val_loss: 0.9919 - val_accuracy: 0.7363 - val_precision: 0.7363 - val_recall: 1.0000
# Epoch 5/25
# 65/65 [==============================] - 44s 681ms/step - loss: 0.1197 - accuracy: 0.9555 - precision: 0.9837 - recall: 0.9560 - val_loss: 1.0606 - val_accuracy: 0.7354 - val_precision: 0.7354 - val_recall: 1.0000
# Epoch 6/25
# 65/65 [==============================] - 45s 705ms/step - loss: 0.0929 - accuracy: 0.9688 - precision: 0.9901 - recall: 0.9677 - val_loss: 1.1829 - val_accuracy: 0.7344 - val_precision: 0.7344 - val_recall: 1.0000
# Epoch 7/25
# 65/65 [==============================] - 45s 699ms/step - loss: 0.0853 - accuracy: 0.9738 - precision: 0.9895 - recall: 0.9751 - val_loss: 1.3074 - val_accuracy: 0.7344 - val_precision: 0.7344 - val_recall: 1.0000
# Epoch 8/25
# 65/65 [==============================] - 44s 688ms/step - loss: 0.0706 - accuracy: 0.9752 - precision: 0.9915 - recall: 0.9752 - val_loss: 1.5039 - val_accuracy: 0.7295 - val_precision: 0.7295 - val_recall: 1.0000
# Epoch 9/25
# 65/65 [==============================] - 45s 697ms/step - loss: 0.0698 - accuracy: 0.9755 - precision: 0.9918 - recall: 0.9751 - val_loss: 1.6212 - val_accuracy: 0.7314 - val_precision: 0.7314 - val_recall: 1.0000
# Epoch 10/25
# 65/65 [==============================] - 45s 695ms/step - loss: 0.0629 - accuracy: 0.9764 - precision: 0.9931 - recall: 0.9751 - val_loss: 1.5646 - val_accuracy: 0.7324 - val_precision: 0.7324 - val_recall: 1.0000
# Epoch 11/25
# 65/65 [==============================] - 45s 696ms/step - loss: 0.0625 - accuracy: 0.9772 - precision: 0.9928 - recall: 0.9765 - val_loss: 1.3498 - val_accuracy: 0.7334 - val_precision: 0.7334 - val_recall: 1.0000
# Epoch 12/25
# 65/65 [==============================] - 45s 699ms/step - loss: 0.0668 - accuracy: 0.9776 - precision: 0.9934 - recall: 0.9763 - val_loss: 0.6538 - val_accuracy: 0.7930 - val_precision: 0.7799 - val_recall: 1.0000
# Epoch 13/25
# 65/65 [==============================] - 44s 682ms/step - loss: 0.0490 - accuracy: 0.9844 - precision: 0.9944 - recall: 0.9844 - val_loss: 0.0863 - val_accuracy: 0.9697 - val_precision: 0.9787 - val_recall: 0.9800
# Epoch 14/25
# 65/65 [==============================] - 45s 699ms/step - loss: 0.0593 - accuracy: 0.9779 - precision: 0.9928 - recall: 0.9775 - val_loss: 0.1224 - val_accuracy: 0.9629 - val_precision: 0.9554 - val_recall: 0.9960
# Epoch 15/25
# 65/65 [==============================] - 44s 685ms/step - loss: 0.0535 - accuracy: 0.9817 - precision: 0.9941 - recall: 0.9814 - val_loss: 0.3646 - val_accuracy: 0.9297 - val_precision: 1.0000 - val_recall: 0.9041
# Epoch 16/25
# 65/65 [==============================] - 45s 699ms/step - loss: 0.0580 - accuracy: 0.9800 - precision: 0.9937 - recall: 0.9792 - val_loss: 0.1566 - val_accuracy: 0.9453 - val_precision: 0.9341 - val_recall: 0.9960
# Epoch 17/25
# 65/65 [==============================] - 45s 698ms/step - loss: 0.0473 - accuracy: 0.9839 - precision: 0.9938 - recall: 0.9845 - val_loss: 0.2218 - val_accuracy: 0.9268 - val_precision: 0.9111 - val_recall: 0.9973
# Epoch 18/25
# 65/65 [==============================] - 44s 683ms/step - loss: 0.0470 - accuracy: 0.9839 - precision: 0.9948 - recall: 0.9835 - val_loss: 0.4169 - val_accuracy: 0.8623 - val_precision: 0.8427 - val_recall: 0.9987
# Epoch 19/25
# 65/65 [==============================] - 46s 707ms/step - loss: 0.0358 - accuracy: 0.9873 - precision: 0.9967 - recall: 0.9862 - val_loss: 0.1314 - val_accuracy: 0.9648 - val_precision: 0.9958 - val_recall: 0.9561
# Epoch 20/25
# 65/65 [==============================] - 45s 698ms/step - loss: 0.0403 - accuracy: 0.9844 - precision: 0.9941 - recall: 0.9848 - val_loss: 0.2066 - val_accuracy: 0.9541 - val_precision: 0.9986 - val_recall: 0.9387
# Epoch 21/25
# 65/65 [==============================] - 45s 695ms/step - loss: 0.0257 - accuracy: 0.9892 - precision: 0.9974 - recall: 0.9881 - val_loss: 0.2554 - val_accuracy: 0.9443 - val_precision: 0.9986 - val_recall: 0.9254
# Epoch 22/25
# 65/65 [==============================] - 45s 697ms/step - loss: 0.0317 - accuracy: 0.9901 - precision: 0.9974 - recall: 0.9893 - val_loss: 0.1619 - val_accuracy: 0.9580 - val_precision: 0.9986 - val_recall: 0.9441
# Epoch 23/25
# 65/65 [==============================] - 44s 689ms/step - loss: 0.0332 - accuracy: 0.9873 - precision: 0.9968 - recall: 0.9862 - val_loss: 0.1041 - val_accuracy: 0.9746 - val_precision: 0.9866 - val_recall: 0.9788
# Epoch 24/25
# 65/65 [==============================] - 45s 693ms/step - loss: 0.0432 - accuracy: 0.9849 - precision: 0.9944 - recall: 0.9851 - val_loss: 0.2985 - val_accuracy: 0.9170 - val_precision: 1.0000 - val_recall: 0.8865
# Epoch 25/25
# 65/65 [==============================] - 45s 702ms/step - loss: 0.0559 - accuracy: 0.9803 - precision: 0.9935 - recall: 0.9802 - val_loss: 0.1117 - val_accuracy: 0.9619 - val_precision: 0.9958 - val_recall: 0.9521

# %% [markdown]
# ## 결과확인

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# loss, accuracy, precision, recall 값을 출력

# %%
loss, accuracy, precision, recall = model.evaluate(test_ds)
print(f'Loss: {loss},\nAccuracy: {accuracy},\nPrecision: {precision},\nRecall: {recall}')
# Out:
# 10/10 [==============================] - 5s 453ms/step - loss: 0.7846 - accuracy: 0.7981 - precision: 0.7651 - recall: 0.9769
# Loss: 0.7846221327781677,
# Accuracy: 0.7980769276618958,
# Precision: 0.7650602459907532,
# Recall: 0.9769230484962463

# %% [markdown]
# ## 진단기 성능개선

# %% [markdown]
# #### Batch size, Epoch 등을 변경

# %% [markdown]
# ## Augmentation : Random B/S, Random Resize / crop, Regularization : BatchNorm, Dropout

# %%
train_ds = train_list_ds.map(process_path, num_parallel_calls = AUTOTUNE)
val_ds = val_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

# %%
def augment(image,label):
    image = tf.image.random_flip_left_right(image)  # 랜덤하게 좌우를 반전합니다.
    return image,label

def prepare_for_training(ds, shuffle_buffer_size=1000):
    # augment 적용 부분이 배치처리 함수에 추가되었습니다.
    ds = ds.map(
            augment,       # augment 함수 적용
            num_parallel_calls=2
        )
    ds = ds.shuffle(buffer_size=shuffle_buffer_size)
    ds = ds.repeat()
    ds = ds.batch(BATCH_SIZE)
    ds = ds.prefetch(buffer_size=AUTOTUNE)

    return ds

train_ds = prepare_for_training(train_ds)
val_ds = prepare_for_training(val_ds)

# %%
train_ds
# Out:
# <PrefetchDataset shapes: ((None, 180, 180, 3), (None,)), types: (tf.float32, tf.bool)>

# %%
image_batch, label_batch = next(iter(train_ds))

show_batch(image_batch.numpy(), label_batch.numpy())

# %%
weight_for_0 = (1 / COUNT_NORMAL)*(TRAIN_IMG_COUNT)/2.0 
weight_for_1 = (1 / COUNT_PNEUMONIA)*(TRAIN_IMG_COUNT)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for class 0: {:.2f}'.format(weight_for_0))
print('Weight for class 1: {:.2f}'.format(weight_for_1))
# Out:
# Weight for class 0: 1.96
# Weight for class 1: 0.67

# %%
with tf.device('/GPU:0'):
    model = build_model()

    METRICS = [
        'accuracy',
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]
    
    model.compile(
        optimizer='adam',
        loss='binary_crossentropy',
        metrics=METRICS
    )

# %%
with tf.device('/GPU:0'):
    history = model.fit(
        train_ds,
        steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=val_ds,
        validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
        class_weight=class_weight,
    )
# Out:
# Epoch 1/25
# 65/65 [==============================] - 55s 716ms/step - loss: 0.4459 - accuracy: 0.7757 - precision: 0.9490 - recall: 0.7385 - val_loss: 0.6084 - val_accuracy: 0.7334 - val_precision: 0.7334 - val_recall: 1.0000
# Epoch 2/25
# 65/65 [==============================] - 46s 713ms/step - loss: 0.2272 - accuracy: 0.9091 - precision: 0.9778 - recall: 0.8982 - val_loss: 0.6622 - val_accuracy: 0.7334 - val_precision: 0.7334 - val_recall: 1.0000
# Epoch 3/25
# 65/65 [==============================] - 47s 724ms/step - loss: 0.1716 - accuracy: 0.9370 - precision: 0.9774 - recall: 0.9370 - val_loss: 0.8232 - val_accuracy: 0.7324 - val_precision: 0.7324 - val_recall: 1.0000
# Epoch 4/25
# 65/65 [==============================] - 48s 753ms/step - loss: 0.1486 - accuracy: 0.9510 - precision: 0.9865 - recall: 0.9470 - val_loss: 0.9289 - val_accuracy: 0.7354 - val_precision: 0.7354 - val_recall: 1.0000
# Epoch 5/25
# 65/65 [==============================] - 51s 792ms/step - loss: 0.1494 - accuracy: 0.9469 - precision: 0.9823 - recall: 0.9458 - val_loss: 0.9516 - val_accuracy: 0.7324 - val_precision: 0.7324 - val_recall: 1.0000
# Epoch 6/25
# 65/65 [==============================] - 44s 678ms/step - loss: 0.1175 - accuracy: 0.9548 - precision: 0.9840 - recall: 0.9546 - val_loss: 1.0232 - val_accuracy: 0.7354 - val_precision: 0.7354 - val_recall: 1.0000
# Epoch 7/25
# 65/65 [==============================] - 44s 684ms/step - loss: 0.1134 - accuracy: 0.9589 - precision: 0.9877 - recall: 0.9567 - val_loss: 1.1253 - val_accuracy: 0.7354 - val_precision: 0.7354 - val_recall: 1.0000
# Epoch 8/25
# 65/65 [==============================] - 45s 692ms/step - loss: 0.1126 - accuracy: 0.9584 - precision: 0.9858 - recall: 0.9583 - val_loss: 1.2486 - val_accuracy: 0.7334 - val_precision: 0.7334 - val_recall: 1.0000
# Epoch 9/25
# 65/65 [==============================] - 44s 686ms/step - loss: 0.0937 - accuracy: 0.9668 - precision: 0.9887 - recall: 0.9663 - val_loss: 1.3543 - val_accuracy: 0.7324 - val_precision: 0.7324 - val_recall: 1.0000
# Epoch 10/25
# 65/65 [==============================] - 43s 674ms/step - loss: 0.0884 - accuracy: 0.9659 - precision: 0.9903 - recall: 0.9634 - val_loss: 1.5014 - val_accuracy: 0.7305 - val_precision: 0.7305 - val_recall: 1.0000
# Epoch 11/25
# 65/65 [==============================] - 45s 697ms/step - loss: 0.0730 - accuracy: 0.9731 - precision: 0.9918 - recall: 0.9719 - val_loss: 1.6258 - val_accuracy: 0.7334 - val_precision: 0.7334 - val_recall: 1.0000
# Epoch 12/25
# 65/65 [==============================] - 45s 706ms/step - loss: 0.0785 - accuracy: 0.9733 - precision: 0.9924 - recall: 0.9716 - val_loss: 0.0708 - val_accuracy: 0.9746 - val_precision: 0.9801 - val_recall: 0.9853
# Epoch 13/25
# 65/65 [==============================] - 44s 679ms/step - loss: 0.0761 - accuracy: 0.9712 - precision: 0.9921 - recall: 0.9690 - val_loss: 0.1636 - val_accuracy: 0.9365 - val_precision: 0.9206 - val_recall: 1.0000
# Epoch 14/25
# 65/65 [==============================] - 45s 693ms/step - loss: 0.0696 - accuracy: 0.9743 - precision: 0.9921 - recall: 0.9732 - val_loss: 0.1123 - val_accuracy: 0.9648 - val_precision: 0.9945 - val_recall: 0.9574
# Epoch 15/25
# 65/65 [==============================] - 44s 680ms/step - loss: 0.0661 - accuracy: 0.9745 - precision: 0.9925 - recall: 0.9733 - val_loss: 0.1598 - val_accuracy: 0.9414 - val_precision: 0.9290 - val_recall: 0.9960
# Epoch 16/25
# 65/65 [==============================] - 45s 697ms/step - loss: 0.0763 - accuracy: 0.9721 - precision: 0.9918 - recall: 0.9706 - val_loss: 1.0301 - val_accuracy: 0.7432 - val_precision: 0.7409 - val_recall: 1.0000
# Epoch 17/25
# 65/65 [==============================] - 44s 689ms/step - loss: 0.0606 - accuracy: 0.9764 - precision: 0.9941 - recall: 0.9742 - val_loss: 0.0852 - val_accuracy: 0.9707 - val_precision: 0.9945 - val_recall: 0.9653
# Epoch 18/25
# 65/65 [==============================] - 45s 690ms/step - loss: 0.0571 - accuracy: 0.9791 - precision: 0.9941 - recall: 0.9777 - val_loss: 0.2026 - val_accuracy: 0.9258 - val_precision: 0.9099 - val_recall: 0.9987
# Epoch 19/25
# 65/65 [==============================] - 45s 693ms/step - loss: 0.0603 - accuracy: 0.9767 - precision: 0.9902 - recall: 0.9783 - val_loss: 0.1093 - val_accuracy: 0.9639 - val_precision: 0.9986 - val_recall: 0.9521
# Epoch 20/25
# 65/65 [==============================] - 45s 695ms/step - loss: 0.0715 - accuracy: 0.9721 - precision: 0.9921 - recall: 0.9704 - val_loss: 0.5256 - val_accuracy: 0.8457 - val_precision: 1.0000 - val_recall: 0.7907
# Epoch 21/25
# 65/65 [==============================] - 43s 663ms/step - loss: 0.0528 - accuracy: 0.9808 - precision: 0.9954 - recall: 0.9786 - val_loss: 0.3292 - val_accuracy: 0.9141 - val_precision: 1.0000 - val_recall: 0.8827
# Epoch 22/25
# 65/65 [==============================] - 45s 704ms/step - loss: 0.0427 - accuracy: 0.9853 - precision: 0.9964 - recall: 0.9839 - val_loss: 0.4304 - val_accuracy: 0.9033 - val_precision: 1.0000 - val_recall: 0.8689
# Epoch 23/25
# 65/65 [==============================] - 44s 684ms/step - loss: 0.0484 - accuracy: 0.9827 - precision: 0.9951 - recall: 0.9816 - val_loss: 1.8995 - val_accuracy: 0.6133 - val_precision: 1.0000 - val_recall: 0.4734
# Epoch 24/25
# 65/65 [==============================] - 45s 691ms/step - loss: 0.0486 - accuracy: 0.9820 - precision: 0.9954 - recall: 0.9804 - val_loss: 0.7372 - val_accuracy: 0.8262 - val_precision: 1.0000 - val_recall: 0.7623
# Epoch 25/25
# 65/65 [==============================] - 42s 659ms/step - loss: 0.0374 - accuracy: 0.9861 - precision: 0.9974 - recall: 0.9838 - val_loss: 0.1252 - val_accuracy: 0.9658 - val_precision: 0.9917 - val_recall: 0.9611

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 5))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %%
loss, acc, prec, rec = model.evaluate(test_ds)
# Out:
# 10/10 [==============================] - 4s 393ms/step - loss: 0.9275 - accuracy: 0.8029 - precision: 0.7686 - recall: 0.9795

# %% [markdown]
# ### batchnorm제거

# %%
train_ds = train_list_ds.map(process_path, num_parallel_calls = AUTOTUNE)
val_ds = val_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

# %%
def augment(image,label):
    image = tf.image.random_flip_left_right(image)  # 랜덤하게 좌우를 반전합니다.
    return image,label

def prepare_for_training(ds, shuffle_buffer_size=1000):
    # augment 적용 부분이 배치처리 함수에 추가되었습니다.
    ds = ds.map(
            augment,       # augment 함수 적용
            num_parallel_calls=2
        )
    ds = ds.shuffle(buffer_size=shuffle_buffer_size)
    ds = ds.repeat()
    ds = ds.batch(BATCH_SIZE)
    ds = ds.prefetch(buffer_size=AUTOTUNE)

    return ds

train_ds = prepare_for_training(train_ds)
val_ds = prepare_for_training(val_ds)

# %%
image_batch, label_batch = next(iter(train_ds))

show_batch(image_batch.numpy(), label_batch.numpy())

# %%
def conv_block(filters):
    block = tf.keras.Sequential([
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPool2D()
    ]
    )
    
    return block

# %%
def dense_block(units, dropout_rate):
    block = tf.keras.Sequential([
        tf.keras.layers.Dense(units, activation='relu'),
        tf.keras.layers.Dropout(dropout_rate)
    ])
    
    return block

# %%
def build_model():
    model = tf.keras.Sequential([
        tf.keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)),
        
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.MaxPool2D(),
        
        conv_block(32),
        conv_block(64),
        
        conv_block(128),
        tf.keras.layers.Dropout(0.2),
        
        conv_block(256),
        tf.keras.layers.Dropout(0.2),
        
        tf.keras.layers.Flatten(),
        dense_block(512, 0.7),
        dense_block(128, 0.5),
        dense_block(64, 0.3),
        
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])
    
    return model

# %%
weight_for_0 = (1 / COUNT_NORMAL)*(TRAIN_IMG_COUNT)/2.0 
weight_for_1 = (1 / COUNT_PNEUMONIA)*(TRAIN_IMG_COUNT)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for class 0: {:.2f}'.format(weight_for_0))
print('Weight for class 1: {:.2f}'.format(weight_for_1))
# Out:
# Weight for class 0: 1.96
# Weight for class 1: 0.67

# %%
with tf.device('/GPU:0'):
    model = build_model()

    METRICS = [
        'accuracy',
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]
    
    model.compile(
        optimizer='adam',
        loss='binary_crossentropy',
        metrics=METRICS
    )

# %%
with tf.device('/GPU:0'):
    history = model.fit(
        train_ds,
        steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=val_ds,
        validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
        class_weight=class_weight,
    )
# Out:
# Epoch 1/25
# 65/65 [==============================] - 55s 718ms/step - loss: 0.4028 - accuracy: 0.7844 - precision: 0.9393 - recall: 0.7594 - val_loss: 0.6868 - val_accuracy: 0.7334 - val_precision: 0.7334 - val_recall: 1.0000
# Epoch 2/25
# 65/65 [==============================] - 45s 706ms/step - loss: 0.2144 - accuracy: 0.9127 - precision: 0.9806 - recall: 0.9005 - val_loss: 0.9292 - val_accuracy: 0.7314 - val_precision: 0.7314 - val_recall: 1.0000
# Epoch 3/25
# 65/65 [==============================] - 47s 736ms/step - loss: 0.1730 - accuracy: 0.9337 - precision: 0.9819 - recall: 0.9280 - val_loss: 1.0445 - val_accuracy: 0.7354 - val_precision: 0.7354 - val_recall: 1.0000
# Epoch 4/25
# 65/65 [==============================] - 48s 749ms/step - loss: 0.1283 - accuracy: 0.9531 - precision: 0.9859 - recall: 0.9506 - val_loss: 1.4900 - val_accuracy: 0.7354 - val_precision: 0.7354 - val_recall: 1.0000
# Epoch 5/25
# 65/65 [==============================] - 51s 797ms/step - loss: 0.1146 - accuracy: 0.9601 - precision: 0.9864 - recall: 0.9597 - val_loss: 1.6191 - val_accuracy: 0.7344 - val_precision: 0.7344 - val_recall: 1.0000
# Epoch 6/25
# 65/65 [==============================] - 43s 666ms/step - loss: 0.1158 - accuracy: 0.9579 - precision: 0.9880 - recall: 0.9551 - val_loss: 1.3182 - val_accuracy: 0.7334 - val_precision: 0.7334 - val_recall: 1.0000
# Epoch 7/25
# 65/65 [==============================] - 45s 697ms/step - loss: 0.1037 - accuracy: 0.9603 - precision: 0.9867 - recall: 0.9595 - val_loss: 1.9768 - val_accuracy: 0.7334 - val_precision: 0.7334 - val_recall: 1.0000
# Epoch 8/25
# 65/65 [==============================] - 46s 713ms/step - loss: 0.0955 - accuracy: 0.9642 - precision: 0.9897 - recall: 0.9621 - val_loss: 2.4892 - val_accuracy: 0.7334 - val_precision: 0.7334 - val_recall: 1.0000
# Epoch 9/25
# 65/65 [==============================] - 44s 688ms/step - loss: 0.0816 - accuracy: 0.9688 - precision: 0.9907 - recall: 0.9669 - val_loss: 3.7655 - val_accuracy: 0.7354 - val_precision: 0.7354 - val_recall: 1.0000
# Epoch 10/25
# 65/65 [==============================] - 45s 705ms/step - loss: 0.0776 - accuracy: 0.9733 - precision: 0.9915 - recall: 0.9727 - val_loss: 3.2576 - val_accuracy: 0.7324 - val_precision: 0.7324 - val_recall: 1.0000
# Epoch 11/25
# 65/65 [==============================] - 46s 709ms/step - loss: 0.0723 - accuracy: 0.9721 - precision: 0.9930 - recall: 0.9693 - val_loss: 0.7702 - val_accuracy: 0.8047 - val_precision: 0.7893 - val_recall: 1.0000
# Epoch 12/25
# 65/65 [==============================] - 45s 691ms/step - loss: 0.0628 - accuracy: 0.9755 - precision: 0.9928 - recall: 0.9742 - val_loss: 0.3668 - val_accuracy: 0.9023 - val_precision: 0.8833 - val_recall: 0.9987
# Epoch 13/25
# 65/65 [==============================] - 45s 696ms/step - loss: 0.0653 - accuracy: 0.9733 - precision: 0.9934 - recall: 0.9705 - val_loss: 0.0838 - val_accuracy: 0.9707 - val_precision: 0.9932 - val_recall: 0.9668
# Epoch 14/25
# 65/65 [==============================] - 42s 655ms/step - loss: 0.0616 - accuracy: 0.9786 - precision: 0.9951 - recall: 0.9763 - val_loss: 0.1167 - val_accuracy: 0.9600 - val_precision: 0.9972 - val_recall: 0.9480
# Epoch 15/25
# 65/65 [==============================] - 45s 696ms/step - loss: 0.0479 - accuracy: 0.9812 - precision: 0.9934 - recall: 0.9811 - val_loss: 0.1303 - val_accuracy: 0.9385 - val_precision: 0.9258 - val_recall: 0.9960
# Epoch 16/25
# 65/65 [==============================] - 43s 675ms/step - loss: 0.0633 - accuracy: 0.9760 - precision: 0.9941 - recall: 0.9735 - val_loss: 0.2810 - val_accuracy: 0.8945 - val_precision: 1.0000 - val_recall: 0.8566
# Epoch 17/25
# 65/65 [==============================] - 44s 678ms/step - loss: 0.0404 - accuracy: 0.9841 - precision: 0.9942 - recall: 0.9846 - val_loss: 0.2829 - val_accuracy: 0.9209 - val_precision: 0.9034 - val_recall: 0.9987
# Epoch 18/25
# 65/65 [==============================] - 42s 649ms/step - loss: 0.0481 - accuracy: 0.9803 - precision: 0.9954 - recall: 0.9780 - val_loss: 0.7514 - val_accuracy: 0.8105 - val_precision: 1.0000 - val_recall: 0.7417
# Epoch 19/25
# 65/65 [==============================] - 45s 701ms/step - loss: 0.0517 - accuracy: 0.9798 - precision: 0.9938 - recall: 0.9790 - val_loss: 0.1002 - val_accuracy: 0.9688 - val_precision: 0.9662 - val_recall: 0.9920
# Epoch 20/25
# 65/65 [==============================] - 44s 684ms/step - loss: 0.0359 - accuracy: 0.9865 - precision: 0.9961 - recall: 0.9857 - val_loss: 0.1813 - val_accuracy: 0.9590 - val_precision: 0.9958 - val_recall: 0.9481
# Epoch 21/25
# 65/65 [==============================] - 44s 688ms/step - loss: 0.0493 - accuracy: 0.9827 - precision: 0.9935 - recall: 0.9833 - val_loss: 0.7376 - val_accuracy: 0.7324 - val_precision: 1.0000 - val_recall: 0.6347
# Epoch 22/25
# 65/65 [==============================] - 42s 660ms/step - loss: 0.0559 - accuracy: 0.9772 - precision: 0.9960 - recall: 0.9733 - val_loss: 0.1039 - val_accuracy: 0.9609 - val_precision: 0.9552 - val_recall: 0.9934
# Epoch 23/25
# 65/65 [==============================] - 47s 723ms/step - loss: 0.0569 - accuracy: 0.9781 - precision: 0.9941 - recall: 0.9764 - val_loss: 0.1189 - val_accuracy: 0.9590 - val_precision: 0.9972 - val_recall: 0.9466
# Epoch 24/25
# 65/65 [==============================] - 44s 689ms/step - loss: 0.0410 - accuracy: 0.9849 - precision: 0.9961 - recall: 0.9834 - val_loss: 0.1411 - val_accuracy: 0.9609 - val_precision: 0.9515 - val_recall: 0.9973
# Epoch 25/25
# 65/65 [==============================] - 44s 686ms/step - loss: 0.0357 - accuracy: 0.9868 - precision: 0.9967 - recall: 0.9855 - val_loss: 0.1695 - val_accuracy: 0.9385 - val_precision: 0.9985 - val_recall: 0.9173

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 5))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %%
loss, acc, prec, rec = model.evaluate(test_ds)
# Out:
# 10/10 [==============================] - 4s 373ms/step - loss: 0.5940 - accuracy: 0.8670 - precision: 0.8419 - recall: 0.9692

# %% [markdown]
# # 회고

# %% [markdown]
# ## 프로젝트를 하면서 힘들거나 어려웠던 점

# %% [markdown]
# 역시나 epoch 지옥에 빠졌다. 이보다 힘든건 없다. 학습하다가 끊기는게 반복이 되어 eopch 돌리는 와중에 다른 공부를 하는 게 겁이나기 시작했다.

# %% [markdown]
# ## 프로젝트를 하면서 알아내거나 모호한 점

# %% [markdown]
# 적절한 batch size, 적절한 epoch값을 설정하는 법이 무엇일까?
#
# 처음부터 적절한 batch size, epoch 값을 설정할 수는 없는 걸까?
#
# 왜 쓸데없는 학습을 시키고, 또 시키고 하면서 맞춰가야하는 걸까?
#
# 학습을 시키다보면 학습시킨 것에 또 학습이 되고 하면서 오버피팅이 생기는 것은 어떻게 해결해야 하는걸까?
#
# 라는 것이 알고싶어졌습니다.

# %% [markdown]
# ## 루프릭 평가지표를 맞추기 위해 시도한 점

# %% [markdown]
# Accuracy 85%를 맞추기 위해 batch size를 바꾸고 epoch을 30으로 맞추었더니 24정도에서 오버피팅이 되어 accuracy값이 낮아졌다가 높아졌다가 하면서 오르락내리락하는 모습이 보여 epoch을 25로 다시 바꾸고 batch size만 32, 64 이렇게 바꾸면서 학습시켰다.
#
# Batch Normalization에 대해 공부했지만 조금 더 공부해봐야 할 것 같다.

# %% [markdown]
# ## 자기다짐

# %% [markdown]
# cv, nlp 뭐든 좋다. 불태워보자.
